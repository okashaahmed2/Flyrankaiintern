# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/okashaahmed2/Flyrankaiintern/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Binary Classification :
#WHY
# Does page need to refresh or not (need refresh(1) and Healthy(0))

# Scoring & Ranking:
#Why
# It calculates a probability score (0.0 to 1.0) for each page to generate a ranked priority list.
#This allows content editors to focus on top-value pages first rather than sifting through thousands of unranked pages

# Section 1 Verification Code
import pandas as pd

url = "https://raw.githubusercontent.com/okashaahmed2/Flyrankaiintern/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

print("Task Type Confirmed: Binary Classification & Scoring")
print(f"Total pages to rank/score: {len(df):,}")
# Out:
# Task Type Confirmed: Binary Classification & Scoring
# Total pages to rank/score: 30,000

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
#Target Variables:
# 1(Need refresh) :Page have negative trend (trend_direction=='down') with high or lost impression

#0(Healthy):page with stable or upward performance ((trend_direction!='down'))


import pandas as pd

url = "https://raw.githubusercontent.com/okashaahmed2/Flyrankaiintern/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)


df['target'] = (df['trend_direction'] == 'down').astype(int)


print("Target Column Distribution:")
print(df['target'].value_counts(normalize=True).map('{:.2%}'.format))
print("\nActual Counts:")
print(df['target'].value_counts())
# Out:
# Target Column Distribution:
# target
# 1    54.21%
# 0    45.79%
# Name: proportion, dtype: object
#
# Actual Counts:
# target
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
#Precision@k : if we give top 100 pages to editor and 90 of them actual declining but 10 of them are healty
#its means 10 percent time of editor wasted on healthy pages. precesion directly effect on healthy pages

#RECALL/F1-SCORE
#Recall ensures we aren't being too cautious and missing large chunks of declining pages across the site.
#F1-Score gives us a single balanced number combining both Precision and Recall.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
#UNIT OF ANALYSIS :
#1 Row = 1 Unique Web Page (content_id): Each row represents an individual anonymized URL with its associated search performance,
#traffic engagement, and content metrics measured over a specific timeframe.

#Dataset Scope: 30,000 rows by 45 columns (features + proxy target).
#Target Included: The last column target (1 for declining, 0 for healthy)
#was dynamically derived from trend_direction






import pandas as pd


url = "https://raw.githubusercontent.com/okashaahmed2/Flyrankaiintern/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# 2. Target column create karein
df['target'] = (df['trend_direction'] == 'down').astype(int)

# 3. Dataframe ka unit of analysis print karein
print(f"Dataset Shape: {df.shape[0]:,} rows x {df.shape[1]} columns")
print("Unit of Analysis: 1 row = 1 unique web page\n")


df.head(3)
# Out:
# Dataset Shape: 30,000 rows x 45 columns
# Unit of Analysis: 1 row = 1 unique web page
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ...   ctr avg_position  engagement_rate  scroll_rate  \
# 0     20457.0  ...  0.76         10.6             5.88         4.55
# 1     15562.0  ...  0.05         20.3             0.00        10.00
# 2     23643.0  ...  0.09         36.5             0.00        28.57
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#Multi-Signal Complexity:
# Real search data is messy.
#Predicting true refresh priority requires combining 40+ features simultaneously (e.g., impressions_90d, ctr, avg_position, engagement_rate, word_count).
# Manual if-else logic cannot effectively map these non-linear interactions.

#Avoids Rigid Cutoffs: Fixed rules (e.g., if impressions >= 500) create hard boundaries that misclassify edge cases.
# ML outputs a continuous probability score, offering flexible prioritization for content editors.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
